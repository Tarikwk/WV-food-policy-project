# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pdfplumber
import re

# %%
with pdfplumber.open("C:/Users/user/Desktop/Cohort10/Capstone DATA/2017_DRCCAH_food_insuf.pdf") as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox

# %%
if table:
    df = pd.DataFrame(table[1:], columns=table[0])
    print(df.head())
else:
    print("No table found.")
# Out:
#   Indicator 6.26: Which of these statements best describes the food situation in this child’s household in\nthe past 12 months?  \
# 0
# 1                                                  %
# 2                                               C.I.
# 3                                       Sample Count
# 4                                          Pop. Est.
#
#                                                 None  \
# 0  We could always afford\nto eat good nutritious...
# 1                                               60.6
# 2                                        53.9 - 66.9
# 3                                                247
# 4                                            223,683
#
#                                                 None  \
# 0  We could always afford\nenough to eat but not\...
# 1                                               35.4
# 2                                        29.3 - 42.2
# 3                                                116
# ...

# %%
raw_table = [
    [
        "We could always afford to eat good nutritious food",
        "60.6", "53.9 - 66.9", "247", "223,683"
    ],
    [
        "We could always afford enough to eat but not always healthy food",
        "35.4", "29.3 - 42.2", "116", "130,797"
    ],
    [
        "Sometimes we could not afford enough to eat",
        "2.6", "1.3 - 5.4", "10", "9,734"
    ],
    [
        "Often we could not afford enough to eat",
        "1.3", "0.3 - 5.0", "2", "4,776"
    ]
]

# Column headers
columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]

# Create cleaned DataFrame
df_clean = pd.DataFrame(raw_table, columns=columns)

# Optional: format numbers
df_clean["%"] = df_clean["%"].astype(float)
df_clean["Sample Count"] = df_clean["Sample Count"].astype(int)
df_clean["Pop. Est."] = df_clean["Pop. Est."].str.replace(",", "").astype(int)

df_clean
# Out:
#                                             Response     %         C.I.  \
# 0  We could always afford to eat good nutritious ...  60.6  53.9 - 66.9
# 1  We could always afford enough to eat but not a...  35.4  29.3 - 42.2
# 2        Sometimes we could not afford enough to eat   2.6    1.3 - 5.4
# 3            Often we could not afford enough to eat   1.3    0.3 - 5.0
#
#    Sample Count  Pop. Est.
# 0           247     223683
# 1           116     130797
# 2            10       9734
# 3             2       4776

# %%
foodinsuf2017 = df_clean

# %%
with pdfplumber.open("C:/Users/user/Desktop/Cohort10/Capstone DATA/2018_DRCCAH_food_insuf.pdf") as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox

# %%
if table:
    df = pd.DataFrame(table[1:], columns=table[0])
    print(df.head())
else:
    print("No table found.")
# Out:
#   Indicator 6.26: Which of these statements best describes your household's ability to afford the food you\nneed during the past 12 months?  \
# 0
# 1                                                  %
# 2                                               C.I.
# 3                                       Sample Count
# 4                                          Pop. Est.
#
#                                                 None  \
# 0  We could always afford\nto eat good nutritious...
# 1                                               59.7
# 2                                        54.4 - 64.8
# 3                                                415
# 4                                            218,808
#
#                                                 None  \
# 0  We could always afford\nenough to eat but not\...
# 1                                               34.3
# 2                                        29.5 - 39.5
# 3                                                210
# ...

# %%
raw_table = [
    [
        "We could always afford to eat good nutritious food",
        "59.7 ", "54.4 - 64.8", "415", "218,808"
    ],
    [
        "We could always afford enough to eat but not always healthy food",
        "34.3", "29.5 - 39.5", "210", "125,780"
    ],
    [
        "Sometimes we could not afford enough to eat",
        "4.8", "2.9 - 7.8", "21", "17,546"
    ],
    [
        "Often we could not afford enough to eat",
        "1.2", "0.5 - 3.1", "5", "4,380"
    ]
]

# Column headers
columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]

# Create cleaned DataFrame
df_clean = pd.DataFrame(raw_table, columns=columns)

# Optional: format numbers
df_clean["%"] = df_clean["%"].astype(float)
df_clean["Sample Count"] = df_clean["Sample Count"].astype(int)
df_clean["Pop. Est."] = df_clean["Pop. Est."].str.replace(",", "").astype(int)

foodinsuf2018 = df_clean

# %%
columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]

# %%
foodinsuf2018 = pd.DataFrame(raw_table, columns=columns)

# Optional: format numbers
foodinsuf2018["%"] = foodinsuf2018["%"].astype(float)
foodinsuf2018["Sample Count"] = foodinsuf2018["Sample Count"].astype(int)
foodinsuf2018["Pop. Est."] = foodinsuf2018["Pop. Est."].str.replace(",", "").astype(int)

foodinsuf2018
# Out:
#                                             Response     %         C.I.  \
# 0  We could always afford to eat good nutritious ...  59.7  54.4 - 64.8
# 1  We could always afford enough to eat but not a...  34.3  29.5 - 39.5
# 2        Sometimes we could not afford enough to eat   4.8    2.9 - 7.8
# 3            Often we could not afford enough to eat   1.2    0.5 - 3.1
#
#    Sample Count  Pop. Est.
# 0           415     218808
# 1           210     125780
# 2            21      17546
# 3             5       4380

# %%
with pdfplumber.open("C:/Users/user/Desktop/Cohort10/Capstone DATA/2019_DRCCAH_food_insuf.pdf") as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox

# %%
if table:
    df = pd.DataFrame(table[1:], columns=table[0])
    print(df.head())
else:
    print("No table found.")
# Out:
#   Indicator 6.26: Which of these statements best describes your household's ability to afford the food you\nneed during the past 12 months?  \
# 0
# 1                                                  %
# 2                                               C.I.
# 3                                       Sample Count
# 4                                          Pop. Est.
#
#                                                 None  \
# 0  We could always afford\nto eat good nutritious...
# 1                                               59.1
# 2                                        53.7 - 64.4
# 3                                                374
# 4                                            208,807
#
#                                                 None  \
# 0  We could always afford\nenough to eat but not\...
# 1                                               34.2
# 2                                        29.2 - 39.6
# 3                                                175
# ...

# %%
raw_table = [
    [
        "We could always afford to eat good nutritious food",
        "59.1 ", "53.7 - 64.4", "374", "208,807"
    ],
    [
        "We could always afford enough to eat but not always healthy food",
        "34.2", "29.2 - 39.6", "175", "120,735"
    ],
    [
        "Sometimes we could not afford enough to eat",
        "6.1", "3.9 - 9.5", "27", "21,592"
    ],
    [
        "Often we could not afford enough to eat",
        "0.5", "0.2 - 1.6", "4", "1,899"
    ]
]


columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]


df_clean = pd.DataFrame(raw_table, columns=columns)


df_clean["%"] = df_clean["%"].astype(float)
df_clean["Sample Count"] = df_clean["Sample Count"].astype(int)
df_clean["Pop. Est."] = df_clean["Pop. Est."].str.replace(",", "").astype(int)

foodinsuf2019 = df_clean

# %%
foodinsuf2019
# Out:
#                                             Response     %         C.I.  \
# 0  We could always afford to eat good nutritious ...  59.1  53.7 - 64.4
# 1  We could always afford enough to eat but not a...  34.2  29.2 - 39.6
# 2        Sometimes we could not afford enough to eat   6.1    3.9 - 9.5
# 3            Often we could not afford enough to eat   0.5    0.2 - 1.6
#
#    Sample Count  Pop. Est.
# 0           374     208807
# 1           175     120735
# 2            27      21592
# 3             4       1899

# %%
with pdfplumber.open("C:/Users/user/Desktop/Cohort10/Capstone DATA/2021_DRCCAH_food_insuf.pdf") as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox

# %%
if table:
    df = pd.DataFrame(table[1:], columns=table[0])
    print(df.head())
else:
    print("No table found.")
# Out:
#   Indicator 6.26: Which of these statements best describes your household's ability to afford the food you\nneed during the past 12 months?  \
# 0
# 1                                                  %
# 2                                               C.I.
# 3                                       Sample Count
# 4                                          Pop. Est.
#
#                                                 None  \
# 0  We could always afford\nto eat good nutritious...
# 1                                               69.8
# 2                                        65.3 - 73.9
# 3                                                633
# 4                                            242,295
#
#                                                 None  \
# 0  We could always afford\nenough to eat but not\...
# 1                                               27.0
# 2                                        23.0 - 31.4
# 3                                                213
# ...

# %%
raw_table = [
    [
        "We could always afford to eat good nutritious food",
        "69.8 ", "65.3 - 73.9", "633", "242,295"
    ],
    [
        "We could always afford enough to eat but not always healthy food",
        "27.0", "23.0 - 31.4", "213", "93,789"
    ],
    [
        "Sometimes we could not afford enough to eat",
        "2.9", "1.7 - 5.0", "20", "10,062"
    ],
    [
        "Often we could not afford enough to eat",
        "0.3", "0.1 - 1.0", "4", "1,099"
    ]
]


columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]


df_clean = pd.DataFrame(raw_table, columns=columns)


df_clean["%"] = df_clean["%"].astype(float)
df_clean["Sample Count"] = df_clean["Sample Count"].astype(int)
df_clean["Pop. Est."] = df_clean["Pop. Est."].str.replace(",", "").astype(int)

foodinsuf2021 = df_clean

# %%
with pdfplumber.open("C:/Users/user/Desktop/Cohort10/Capstone DATA/2022_DRCCAH_food_insuf.pdf") as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox

# %%
if table:
    df = pd.DataFrame(table[1:], columns=table[0])
    print(df.head())
else:
    print("No table found.")
# Out:
#   Indicator 6.26: Which of these statements best describes your household's ability to afford the food you\nneed during the past 12 months?  \
# 0
# 1                                                  %
# 2                                               C.I.
# 3                                       Sample Count
# 4                                          Pop. Est.
#
#                                                 None  \
# 0  We could always afford\nto eat good nutritious...
# 1                                               57.8
# 2                                        53.1 - 62.2
# 3                                                506
# 4                                            203,377
#
#                                                 None  \
# 0  We could always afford\nenough to eat but not\...
# 1                                               37.9
# 2                                        33.5 - 42.6
# 3                                                284
# ...

# %%
raw_table = [
    [
        "We could always afford to eat good nutritious food",
        "57.8 ", "53.1 - 62.2", "506", "203,377"
    ],
    [
        "We could always afford enough to eat but not always healthy food",
        "37.9", "33.5 - 42.6", "284", "133,622"
    ],
    [
        "Sometimes we could not afford enough to eat",
        "3.6", "2.4 - 5.5", "29", "12,812"
    ],
    [
        "Often we could not afford enough to eat",
        "0.7", "0.2 - 2.1", "4", "2,348"
    ]
]


columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]


df_clean = pd.DataFrame(raw_table, columns=columns)


df_clean["%"] = df_clean["%"].astype(float)
df_clean["Sample Count"] = df_clean["Sample Count"].astype(int)
df_clean["Pop. Est."] = df_clean["Pop. Est."].str.replace(",", "").astype(int)

foodinsuf2022 = df_clean

# %%
with pdfplumber.open("C:/Users/user/Desktop/Cohort10/Capstone DATA/2023_DRCCAH_food_insuf.pdf") as pdf:
    page = pdf.pages[0]
    table = page.extract_table()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox

# %%
if table:
    df = pd.DataFrame(table[1:], columns=table[0])
    print(df.head())
else:
    print("No table found.")
# Out:
#   Indicator 6.26: Which of these statements best describes your household’s ability to afford the food you\nneed during the past 12 months?  \
# 0
# 1                                                  %
# 2                                               C.I.
# 3                                       Sample Count
# 4                                          Pop. Est.
#
#                                                 None  \
# 0  We could always afford\nto eat good nutritious...
# 1                                               55.9
# 2                                        51.0 - 60.6
# 3                                                460
# 4                                            189,851
#
#                                                 None  \
# 0  We could always afford\nenough to eat but not\...
# 1                                               37.3
# 2                                        32.9 - 42.0
# 3                                                273
# ...

# %%
raw_table = [
    [
        "We could always afford to eat good nutritious food",
        "55.9 ", "51.0 - 60.6", "460", "189,851"
    ],
    [
        "We could always afford enough to eat but not always healthy food",
        "37.3", "32.9 - 42.0", "273", "126,866"
    ],
    [
        "Sometimes we could not afford enough to eat",
        "6.2", "4.0 - 9.6", "33", "21,212"
    ],
    [
        "Often we could not afford enough to eat",
        "0.5", "0.2 - 1.6", "4", "1,852"
    ]
]


columns = ["Response", "%", "C.I.", "Sample Count", "Pop. Est."]


df_clean = pd.DataFrame(raw_table, columns=columns)


df_clean["%"] = df_clean["%"].astype(float)
df_clean["Sample Count"] = df_clean["Sample Count"].astype(int)
df_clean["Pop. Est."] = df_clean["Pop. Est."].str.replace(",", "").astype(int)

foodinsuf2023 = df_clean

# %%
foodinsuf2023
# Out:
#                                             Response     %         C.I.  \
# 0  We could always afford to eat good nutritious ...  55.9  51.0 - 60.6
# 1  We could always afford enough to eat but not a...  37.3  32.9 - 42.0
# 2        Sometimes we could not afford enough to eat   6.2    4.0 - 9.6
# 3            Often we could not afford enough to eat   0.5    0.2 - 1.6
#
#    Sample Count  Pop. Est.
# 0           460     189851
# 1           273     126866
# 2            33      21212
# 3             4       1852

# %%
foodinsuf2017 = foodinsuf2017.melt(id_vars=[foodinsuf2017.columns[0]], value_name = '2017')

# %%
foodinsuf2018 = foodinsuf2018.melt(id_vars=[foodinsuf2018.columns[0]], value_name = '2018')

# %%
foodinsuf2019 = foodinsuf2019.melt(id_vars=[foodinsuf2019.columns[0]], value_name = '2019')

# %%
foodinsuf2021 = foodinsuf2021.melt(id_vars=[foodinsuf2021.columns[0]], value_name = '2021')

# %%
foodinsuf2022 = foodinsuf2022.melt(id_vars=[foodinsuf2022.columns[0]], value_name = '2022')

# %%
foodinsuf2023 = foodinsuf2023.melt(id_vars=[foodinsuf2023.columns[0]], value_name = '2023')

# %%
dfs = [foodinsuf2017, foodinsuf2018, foodinsuf2019, foodinsuf2021, foodinsuf2022, foodinsuf2023]

# %%
merged_df = dfs[0]

# %%
for i, df in enumerate(dfs):
    dfs[i] = df.set_index(['Response'])

# %%
merged_df = pd.concat(dfs, axis=1)

# %%
merged_df = merged_df.reset_index()

# %%
DRCCAHdf = merged_df

# %%
DRCCAHdf.to_csv('DRCCAHdf.csv', index=False)

# %%
DRCCAHdf
# Out:
#                                              Response      variable  \
# 0   We could always afford to eat good nutritious ...             %
# 1   We could always afford enough to eat but not a...             %
# 2         Sometimes we could not afford enough to eat             %
# 3             Often we could not afford enough to eat             %
# 4   We could always afford to eat good nutritious ...          C.I.
# 5   We could always afford enough to eat but not a...          C.I.
# 6         Sometimes we could not afford enough to eat          C.I.
# 7             Often we could not afford enough to eat          C.I.
# 8   We could always afford to eat good nutritious ...  Sample Count
# 9   We could always afford enough to eat but not a...  Sample Count
# 10        Sometimes we could not afford enough to eat  Sample Count
# 11            Often we could not afford enough to eat  Sample Count
# 12  We could always afford to eat good nutritious ...     Pop. Est.
# ...
